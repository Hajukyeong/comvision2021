# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('opencv.png')
n= 5

kernel = np.ones((n,n),np.float32)/(n*n)
dst = cv2.filter2D(img,-1,kernel) # 입력 영상과 동일한  데이터의 출력 영상 생성

plt.rcParams["figure.figsize"]=(20,10)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
np.ones((5,5),np.float32)/25
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]], dtype=float32)

# %%
sum (sum(kernel))
# Out:
# 0.9999998137354851

# %%
img = cv2.imread('check.jpg')
n = 5


blur = cv2.blur(img,(n,n)) # 커널이랑 dst 합친거
GaussianBlur = cv2.GaussianBlur(img,(n,n),0)
medianBlur = cv2.medianBlur(img,n)
bilateralFilter = cv2.bilateralFilter(img,9, 75, 75)

plt.rcParams["figure.figsize"]=(20,10)
plt.subplot(221),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(223),plt.imshow(img),plt.title('GaussianBlur')
plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(img),plt.title('bilateralFilter')
plt.xticks([]), plt.yticks([])
plt.show()
